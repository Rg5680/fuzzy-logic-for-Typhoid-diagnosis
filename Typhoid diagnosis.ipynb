# %%
import numpy as npy
import pandas as pd

# %%
df=pd.DataFrame({'FVR':npy.random.randint(96,104,50),
                'NAU':npy.random.randint(1,11,50),
                'BWS':npy.random.randint(1,11,50),
                'LAE':npy.random.randint(1,11,50)})
print(df)
# Out:
#     FVR  NAU  BWS  LAE
# 0    97    8    7   10
# 1   100    3    2    6
# 2    98    6    4    9
# 3   100    5    2    1
# 4   102    2    1    4
# 5   101    4    4    8
# 6   103    5    6    3
# 7    99    9    7    2
# 8    98   10    5    1
# 9    96    6    7    6
# 10   96    3    3    9
# 11  102    8    2    5
# 12  103    1    3    7
# 13  103   10    4    7
# 14  101    2    7    5
# 15   96    2    7    2
# 16  100    4    6    6
# 17   99    3   10    7
# 18   98   10   10    2
# 19   97   10    3    3
# 20  100    7    7    7
# 21  103    2    2    6
# 22   96    3    8    1
# 23  100   10    4    8
# 24  103    9    1    8
# 25  101    8    4    5
# 26   98    4   10    1
# 27   96    9    7    6
# 28  100    6    7    9
# 29   96    4    2    5
# 30  101    9    6    8
# 31   97    9    4    6
# 32   97    2    9    1
# 33   99    1    5    3
# 34   97    6    6    3
# 35   97    2    7    8
# 36   97    4    7    1
# 37  101    5   10   10
# 38  101    7    9    9
# ...

# %%
import numpy as np
import skfuzzy as fuzzy
from skfuzzy import control as ctrl
import matplotlib.pyplot as plt

# %%
Fever=ctrl.Antecedent(np.arange(96,104,1),'Fever')
Fever['mild']=fuzzy.trimf(Fever.universe,[96,96,97.5])
Fever['moderate']=fuzzy.trimf(Fever.universe,[97,98,99])
Fever['severe']=fuzzy.trimf(Fever.universe,[98.5,100,101])
Fever['very_severe']=fuzzy.trapmf(Fever.universe,[100.5,102,103,103])
Fever.view()
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Nausea=ctrl.Antecedent(np.arange(1,11,1),'Nausea')
Nausea['mild']=fuzzy.trimf(Nausea.universe,[1,1,3])
Nausea['moderate']=fuzzy.trapmf(Nausea.universe,[2,3,4,5])
Nausea['severe']=fuzzy.trapmf(Nausea.universe,[4,6,7,8])
Nausea['very_severe']=fuzzy.trapmf(Nausea.universe,[7,9,10,10])
Nausea.view()
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Bodyweak=ctrl.Antecedent(np.arange(1,11,1),'Bodyweak')
Bodyweak['mild']=fuzzy.trimf(Bodyweak.universe,[1,1,3])
Bodyweak['moderate']=fuzzy.trapmf(Bodyweak.universe,[2,3,4,5])
Bodyweak['severe']=fuzzy.trapmf(Bodyweak.universe,[4,6,7,8])
Bodyweak['very_severe']=fuzzy.trapmf(Bodyweak.universe,[7,9,10,10])
Bodyweak.view()
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Lossappetite=ctrl.Antecedent(np.arange(1,11,1),'Lossappetite')
Lossappetite['mild']=fuzzy.trimf(Lossappetite.universe,[1,1,3])
Lossappetite['moderate']=fuzzy.trapmf(Lossappetite.universe,[2,3,4,5])
Lossappetite['severe']=fuzzy.trapmf(Lossappetite.universe,[4,6,7,8])
Lossappetite['very_severe']=fuzzy.trapmf(Lossappetite.universe,[7,9,10,10])
Lossappetite.view()
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
typhoid=ctrl.Consequent(np.arange(0,21),'typhoid')
typhoid.automf(5)
typhoid.view()
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
rule1=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['poor'])
rule2=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['poor'])
rule3=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['poor'])
rule4=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['mediocre'])
rule5=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['poor'])
rule6=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['poor'])
rule7=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['mediocre'])
rule8=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['mediocre'])
rule9=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['poor'])
rule10=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['mediocre'])
rule11=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['average'])
rule12=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['average'])
rule13=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['poor'])
rule14=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['mediocre'])
rule15=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['average'])
rule16=ctrl.Rule(Fever['mild'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['average'])
rule17=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['poor'])
rule18=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['poor'])
rule19=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['mediocre'])
rule20=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['average'])
rule21=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['poor'])
rule22=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['mediocre'])
rule23=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['average'])
rule24=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['average'])
rule25=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['mediocre'])
rule26=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['average'])
rule27=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['average'])
rule28=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['average'])
rule29=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['mediocre'])
rule30=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['average'])
rule31=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['average'])
rule32=ctrl.Rule(Fever['mild'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['average'])
rule33=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['mediocre'])
rule34=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['mediocre'])
rule35=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['mediocre'])
rule36=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['average'])
rule37=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['mediocre'])
rule38=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['mediocre'])
rule39=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['average'])
rule40=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['average'])
rule41=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['mediocre'])
rule42=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['average'])
rule43=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['average'])
rule44=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['average'])
rule45=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['average'])
rule46=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['average'])
rule47=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['average'])
rule48=ctrl.Rule(Fever['mild'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['average'])
rule49=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['mediocre'])
rule50=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['mediocre'])
rule51=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['average'])
rule52=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['average'])
rule53=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['mediocre'])
rule54=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['mediocre'])
rule55=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['average'])
rule56=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['average'])
rule57=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['mediocre'])
rule58=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['average'])
rule59=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['average'])
rule60=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['average'])
rule61=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['average'])
rule62=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['average'])
rule63=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['average'])
rule64=ctrl.Rule(Fever['mild'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['average'])
rule65=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['poor'])
rule66=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['mediocre'])
rule67=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['mediocre'])
rule68=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['mediocre'])
rule69=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['poor'])
rule70=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['mediocre'])
rule71=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['mediocre'])
rule72=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['mediocre'])
rule73=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['mediocre'])
rule74=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['mediocre'])
rule75=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['average'])
rule76=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['average'])
rule77=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['mediocre'])
rule78=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['mediocre'])
rule79=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['average'])
rule80=ctrl.Rule(Fever['moderate'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['average'])
rule81=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['mediocre'])
rule82=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['mediocre'])
rule83=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['average'])
rule84=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['average'])
rule85=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['mediocre'])
rule86=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['mediocre'])
rule87=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['average'])
rule88=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['average'])
rule89=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['mediocre'])
rule90=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['average'])
rule91=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['average'])
rule92=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['average'])
rule93=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['average'])
rule94=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['average'])
rule95=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['average'])
rule96=ctrl.Rule(Fever['moderate'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['average'])
rule97=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['mediocre'])
rule98=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['average'])
rule99=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['average'])
rule100=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['average'])
rule101=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['mediocre'])
rule102=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['average'])
rule103=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['average'])
rule104=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['average'])
rule105=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['average'])
rule106=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['average'])
rule107=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['average'])
rule108=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['average'])
rule109=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['average'])
rule110=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['average'])
rule111=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['average'])
rule112=ctrl.Rule(Fever['moderate'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['decent'])
rule113=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['average'])
rule114=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['average'])
rule115=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['average'])
rule116=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['average'])
rule117=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['average'])
rule118=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['average'])
rule119=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['average'])
rule120=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['decent'])
rule121=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['average'])
rule122=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['average'])
rule123=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['average'])
rule124=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['average'])
rule125=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['average'])
rule126=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['average'])
rule127=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['decent'])
rule128=ctrl.Rule(Fever['moderate'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['decent'])
rule129=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['mediocre'])
rule130=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['mediocre'])
rule131=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['average'])
rule132=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['average'])
rule133=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['mediocre'])
rule134=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['mediocre'])
rule135=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['average'])
rule136=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['average'])
rule137=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['mediocre'])
rule138=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['average'])
rule139=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['average'])
rule140=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['average'])
rule141=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['average'])
rule142=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['average'])
rule143=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['average'])
rule144=ctrl.Rule(Fever['severe'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['decent'])
rule145=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['mediocre'])
rule146=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['average'])
rule147=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['average'])
rule148=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['average'])
rule149=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['average'])
rule150=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['average'])
rule151=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['average'])
rule152=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['decent'])
rule153=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['average'])
rule154=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['average'])
rule155=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['decent'])
rule156=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['decent'])
rule157=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['average'])
rule158=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['average'])
rule159=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['decent'])
rule160=ctrl.Rule(Fever['severe'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['decent'])
rule161=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['average'])
rule162=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['average'])
rule163=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['average'])
rule164=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['decent'])
rule165=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['average'])
rule166=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['average'])
rule167=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['decent'])
rule168=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['decent'])
rule169=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['average'])
rule170=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['average'])
rule171=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['decent'])
rule172=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['decent'])
rule173=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['decent'])
rule174=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['decent'])
rule175=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['decent'])
rule176=ctrl.Rule(Fever['severe'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['good'])
rule177=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['average'])
rule178=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['average'])
rule179=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['decent'])
rule180=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['decent'])
rule181=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['average'])
rule182=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['decent'])
rule183=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['decent'])
rule184=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['decent'])
rule185=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['decent'])
rule186=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['decent'])
rule187=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['decent'])
rule188=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['decent'])
rule189=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['decent'])
rule190=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['decent'])
rule191=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['good'])
rule192=ctrl.Rule(Fever['severe'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['good'])
rule193=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['mediocre'])
rule194=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['average'])
rule195=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['decent'])
rule196=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['decent'])
rule197=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['average'])
rule198=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['average'])
rule199=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['decent'])
rule200=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['decent'])
rule201=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['average'])
rule202=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['average'])
rule203=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['decent'])
rule204=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['decent'])
rule205=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['average'])
rule206=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['average'])
rule207=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['decent'])
rule208=ctrl.Rule(Fever['very_severe'] & Nausea['mild']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['decent'])
rule209=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['average'])
rule210=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['decent'])
rule211=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['decent'])
rule212=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['decent'])
rule213=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['average'])
rule214=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['decent'])
rule215=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['decent'])
rule216=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['decent'])
rule217=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['average'])
rule218=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['decent'])
rule219=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['decent'])
rule220=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['decent'])
rule221=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['average'])
rule222=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['decent'])
rule223=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['decent'])
rule224=ctrl.Rule(Fever['very_severe'] & Nausea['moderate']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['decent'])
rule225=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['average'])
rule226=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['decent'])
rule227=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['decent'])
rule228=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['decent'])
rule229=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['decent'])
rule230=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['decent'])
rule231=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['decent'])
rule232=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['good'])
rule233=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['decent'])
rule234=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['decent'])
rule235=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['good'])
rule236=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['good'])
rule237=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['decent'])
rule238=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['decent'])
rule239=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['good'])
rule240=ctrl.Rule(Fever['very_severe'] & Nausea['severe']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['good'])
rule241=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['mild'],typhoid['average'])
rule242=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['moderate'],typhoid['decent'])
rule243=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['severe'],typhoid['decent'])
rule244=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['mild'] & Lossappetite['very_severe'],typhoid['good'])
rule245=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['mild'],typhoid['decent'])
rule246=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['moderate'],typhoid['decent'])
rule247=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['severe'],typhoid['good'])
rule248=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['moderate'] & Lossappetite['very_severe'],typhoid['good'])
rule249=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['mild'],typhoid['decent'])
rule250=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['moderate'],typhoid['good'])
rule251=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['severe'],typhoid['good'])
rule252=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['severe'] & Lossappetite['very_severe'],typhoid['good'])
rule253=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['mild'],typhoid['decent'])
rule254=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['moderate'],typhoid['good'])
rule255=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['severe'],typhoid['good'])
rule256=ctrl.Rule(Fever['very_severe'] & Nausea['very_severe']&Bodyweak['very_severe'] & Lossappetite['very_severe'],typhoid['good'])
rule=[rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25,rule26,rule27,rule28,rule29,rule30,rule31,rule32,rule33,rule34,rule35,rule36,rule37,rule38,rule39,rule40,rule41,rule42,rule43,rule44,rule45,rule46,rule47,rule48,rule49,rule50,rule51,rule52,rule53,rule54,rule55,rule56,rule57,rule58,rule59,rule60,rule61,rule62,rule63,rule64,rule65,rule66,rule67,rule68,rule69,rule70,rule71,rule72,rule73,rule74,rule75,rule76,rule77,rule78,rule79,rule80,rule81,rule82,rule83,rule84,rule85,rule86,rule87,rule88,rule89,rule90,rule91,rule92,rule93,rule94,rule95,rule96,rule97,rule98,rule99,rule100,rule101,rule102,rule103,rule104,rule105,rule106,rule107,rule108,rule109,rule110,rule111,rule112,rule113,rule114,rule115,rule116,rule117,rule118,rule119,rule120,rule121,rule122,rule123,rule124,rule125,rule126,rule127,rule128,rule129,rule130,rule131,rule132,rule133,rule134,rule135,rule136,rule137,rule138,rule139,rule140,rule141,rule142,rule143,rule144,rule145,rule146,rule147,rule148,rule149,rule150,rule151,rule152,rule153,rule154,rule155,rule156,rule157,rule158,rule159,rule160,rule161,rule162,rule163,rule164,rule165,rule166,rule167,rule168,rule169,rule170,rule171,rule172,rule173,rule174,rule175,rule176,rule177,rule178,rule179,rule180,rule181,rule182,rule183,rule184,rule185,rule186,rule187,rule188,rule189,rule190,rule191,rule192,rule193,rule194,rule195,rule196,rule197,rule198,rule199,rule200,rule201,rule202,rule203,rule204,rule205,rule206,rule207,rule208,rule209,rule210,rule211,rule212,rule213,rule214,rule215,rule216,rule217,rule218,rule219,rule220,rule221,rule222,rule223,rule224,rule225,rule226,rule227,rule228,rule229,rule230,rule231,rule232,rule233,rule234,rule235,rule236,rule237,rule238,rule239,rule240,rule241,rule242,rule243,rule244,rule245,rule246,rule247,rule248,rule249,rule250,rule251,rule252,rule253,rule254,rule255,rule256]

# %%
x=ctrl.ControlSystem(rule)
y=ctrl.ControlSystemSimulation(x)

# %%
typ_val=[]
typ_con=[]
for i in range(50):
    y.input['Fever']=df._get_value(i,'FVR')
    y.input['Nausea']=df._get_value(i,'NAU')
    y.input['Bodyweak']=df._get_value(i,'BWS')
    y.input['Lossappetite']=df._get_value(i,'LAE')
    y.compute()
    value=y.output['typhoid']
    typ_val.append(value)
    if value<5:
        typ_con.append('Mild')
    elif value<11:
        typ_con.append('Moderate')
    elif value<16:
        typ_con.append('Severe')
    else:
        typ_con.append('Very Severe')

# %%
df['Typhoid_value(0-20)']=typ_val
df['Typhoid_Condition']=typ_con

# %%
print(df)
